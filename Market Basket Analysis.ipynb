# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('D:\ITtools\Dataset\Market_Basket_Optimisation2.csv',header=None)
data.shape
# Out:
# (200, 8)

# %%
rule=[]
for i in range(0,200):
    rule.append([str(data.values[i,j])for j in range(0,8)])

# %%
rule
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['burgers', 'meatballs', 'eggs', 'nan', 'nan', 'nan', 'nan', 'nan'],
#  ['chutney', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'],
#  ['turkey', 'avocado', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'],
#  ['mineral water',
#   'milk',
#   'energy bar',
#   'whole wheat rice',
#   'green tea',
#   'nan',
#   'nan',
#   'nan'],
#  ['low fat yogurt', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'],
#  ['whole wheat pasta',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup', 'light cream', 'shallot', 'nan', 'nan', 'nan', 'nan', 'nan'],
#  ['frozen vegetables',
#   'spaghetti',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'],
#  ['eggs', 'pet food', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'],
# ...

# %%
from apyori import apriori
obj=apriori(rule,min_support=0.05,min_confidence=0.2,min_lift=1.1,min_length=2)
rule2=list(obj)
rule2
# Out:
# [RelationRecord(items=frozenset({'burgers', 'eggs'}), support=0.055, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'eggs'}), confidence=0.47826086956521735, lift=2.224469160768453), OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'burgers'}), confidence=0.2558139534883721, lift=2.224469160768453)]),
#  RelationRecord(items=frozenset({'eggs', 'chocolate'}), support=0.055, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'eggs'}), confidence=0.3333333333333333, lift=1.5503875968992247), OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'chocolate'}), confidence=0.2558139534883721, lift=1.550387596899225)]),
# ...
